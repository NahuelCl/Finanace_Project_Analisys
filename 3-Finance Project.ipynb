# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills.
# ____
#
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
#
# ### The Imports

# %%
from pandas_datareader import data, wb

import yfinance as yf

import seaborn as sns

yf.pdr_override()

import pandas as pd

import numpy as np

import datetime

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
#
#
# ### Bank of America
#    ### BAC = data.DataReader("BAC", 'google', start, end)
#
#
# ------------

# %%
from pandas_datareader import data, wb
import yfinance as yf
yf.pdr_override()
 
start= datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
 
# Bank of America
BAC = data.get_data_yahoo('BAC', start, end)
 
# CitiGroup
C = data.get_data_yahoo('C', start, end)
 
# Goldman Sachs
GS = data.get_data_yahoo('GS', start, end)
 
# JPMorgan Chase
JPM = data.get_data_yahoo('JPM', start, end)
 
# Morgan Stanley
MS = data.get_data_yahoo('MS', start, end)
 
# Wells Fargo
WF = data.get_data_yahoo('WFC', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
JPM
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  39.830002  40.360001  39.299999  40.189999  24.516237  12838600
# 2006-01-04  39.779999  40.139999  39.419998  39.619999  24.374733  13491500
# 2006-01-05  39.610001  39.810001  39.500000  39.740002  24.448553   8109400
# 2006-01-06  39.919998  40.240002  39.549999  40.020000  24.620819   7966900
# 2006-01-09  39.880001  40.720001  39.880001  40.669998  25.020708  16575200
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  66.620003  66.889999  66.320000  66.599998  52.210121   4468200
# 2015-12-28  66.290001  66.449997  65.709999  66.379997  52.037659   6610600
# 2015-12-29  66.839996  67.300003  66.739998  67.070000  52.578594   9820800
# 2015-12-30  67.040001  67.050003  66.449997  66.589996  52.202286   7190700
# 2015-12-31  66.190002  66.779999  66.000000  66.029999  51.763287  14654300
#
# [2517 rows x 6 columns]

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BAC','C','GS','JPM','MS','WF']

# %% [markdown]
# Used pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks and then set the keys argument equal to the tickers list.

# %%
bank_stocks= pd.concat([BAC,C,GS,JPM,MS,WF],axis=1,keys=tickers)
bank_stocks
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  31.544920  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.209898  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.250097  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.203197  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.223297  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.271373  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.155675  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.279634  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.089568  35066400
# ...

# %% [markdown]
#  Set the column name levels:

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  31.544920  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  31.209898  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  31.250097  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  31.203197  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  31.223297  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %% [markdown]
# What is the max Close price for each bank's stock throughout the time period?

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WF      58.520000
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns =  bank_stocks.pct_change().dropna()
returns.head()
# Out:
# Bank Ticker       BAC                                                    \
# Stock Info       Open      High       Low     Close Adj Close    Volume
# Date
# 2006-01-04   0.001705  0.001272  0.006501 -0.010620 -0.010620  0.089662
# 2006-01-05  -0.008936 -0.008679 -0.002799  0.001288  0.001288 -0.156955
# 2006-01-06   0.004723  0.001708  0.000648 -0.001501 -0.001501 -0.158369
# 2006-01-09  -0.001709  0.001279  0.000216  0.000644  0.000644  0.239655
# 2006-01-10  -0.006849 -0.009794 -0.010354 -0.008369 -0.008369  0.000973
#
# Bank Ticker         C                                ...        MS            \
# Stock Info       Open      High       Low     Close  ...       Low     Close
# Date                                                 ...
# 2006-01-04  -0.002857 -0.005670  0.004989 -0.018462  ...  0.028375  0.000686
# 2006-01-05  -0.008596 -0.006517  0.001034  0.004961  ... -0.005655  0.002742
# 2006-01-06   0.009083  0.002460 -0.004132  0.000000  ...  0.000517  0.001025
# ...

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
returns = pd.DataFrame()
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WF Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN        NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686  -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742  -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025   0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586  -0.000158

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns.dropna()
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WF Return    2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WF Return    2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WF Return     0.030238
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31']['MS Return'].std()
# Out:
# 0.016249117170001694

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], kde=True,bins=100,color='black')

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.displot(returns.loc['2008-01-01':'2008-12-31']['MS Return'], kde=True,bins=100)

# %% [markdown]
# ____
# ### Imports

# %%
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)

plt.title('Bank Stocks Close Price Comparison')
plt.legend()  # To show labels of tickers
plt.savefig('bank_stocks_close_price.png')

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="3c94deb2-271b-446b-afc5-215acff64a88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
returns.loc['2008-01-01':'2008-12-31']['BAC Return'].rolling(window=30).mean().iplot()

plt.title('Moving Average Bank of America')
plt.legend()  # To show labels of tickers
plt.savefig('moving_average_bac.png')
# Out:
# <div>                            <div id="eec64611-a8a4-4461-9b1e-5cee83a937d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr())
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>                            <div id="2c4b486e-6969-4f2f-81c2-f8b4cbf8726d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
